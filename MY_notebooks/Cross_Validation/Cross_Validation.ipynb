# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\lenovo\Desktop\Notebooks\DATA\Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
## CREATE X and y
X = df.drop('sales',axis=1)
y = df['sales']

# TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# SCALE DATA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_validate

# %%
from sklearn.linear_model import Ridge

# %%
model  =  Ridge(alpha=100)

# %%
scores = cross_validate(model,X_train,y_train,scoring=['neg_mean_squared_error','neg_mean_absolute_error'],cv=10)

# %%
scores
# Out:
# {'fit_time': array([0.0194757 , 0.00322556, 0.00214314, 0.01401067, 0.00134921,
#         0.00184417, 0.00594878, 0.00149465, 0.        , 0.        ]),
#  'score_time': array([0.00114083, 0.0010221 , 0.00100303, 0.00200438, 0.00100303,
#         0.00100064, 0.00117302, 0.        , 0.        , 0.00601935]),
#  'test_neg_mean_squared_error': array([ -6.06067062, -10.62703078,  -3.99342608,  -5.00949402,
#          -9.14179955, -13.08625636,  -3.83940454,  -9.05878567,
#          -9.05545685,  -5.77888211]),
#  'test_neg_mean_absolute_error': array([-1.8102116 , -2.54195751, -1.46959386, -1.86276886, -2.52069737,
#         -2.45999491, -1.45197069, -2.37739501, -2.44334397, -1.89979708])}

# %%
scores = pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.019476    0.001141                    -6.060671
# 1  0.003226    0.001022                   -10.627031
# 2  0.002143    0.001003                    -3.993426
# 3  0.014011    0.002004                    -5.009494
# 4  0.001349    0.001003                    -9.141800
# 5  0.001844    0.001001                   -13.086256
# 6  0.005949    0.001173                    -3.839405
# 7  0.001495    0.000000                    -9.058786
# 8  0.000000    0.000000                    -9.055457
# 9  0.000000    0.006019                    -5.778882
#
#    test_neg_mean_absolute_error
# 0                     -1.810212
# 1                     -2.541958
# 2                     -1.469594
# 3                     -1.862769
# 4                     -2.520697
# 5                     -2.459995
# 6                     -1.451971
# 7                     -2.377395
# 8                     -2.443344
# 9                     -1.899797

# %%
scores.mean()
# Out:
# fit_time                        0.004949
# score_time                      0.001437
# test_neg_mean_squared_error    -7.565121
# test_neg_mean_absolute_error   -2.083773
# dtype: float64

# %%
model = Ridge(1)

# %%
scores = cross_validate(model,X_train,y_train,scoring=['neg_mean_squared_error','neg_mean_absolute_error'],cv=10)

# %%
scores = pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.001007    0.002434                    -2.962508
# 1  0.001365    0.000000                    -3.057378
# 2  0.001534    0.000000                    -2.173740
# 3  0.001536    0.001380                    -0.833034
# 4  0.001186    0.002043                    -3.464018
# 5  0.001476    0.002063                    -8.232647
# 6  0.000506    0.002527                    -1.905864
# 7  0.002004    0.001574                    -2.765048
# 8  0.002250    0.000563                    -4.989505
# 9  0.003186    0.000000                    -2.846438
#
#    test_neg_mean_absolute_error
# 0                     -1.457174
# 1                     -1.555308
# 2                     -1.238770
# 3                     -0.768938
# 4                     -1.434489
# 5                     -1.494316
# 6                     -1.081362
# 7                     -1.250011
# 8                     -1.580971
# 9                     -1.223326

# %%
scores.mean()
# Out:
# fit_time                        0.001605
# score_time                      0.001258
# test_neg_mean_squared_error    -3.323018
# test_neg_mean_absolute_error   -1.308467
# dtype: float64

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2.319021579428751

# %%
#GROUP__BY

# %%
#we should do the grouping the using an agregate function

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\lenovo\Desktop\Notebooks\03-Pandas\mpg.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#to apply group by we must have a cathegoritical columns:

# %%
df['model_year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype=int64)

# %%
df.groupby('model_year').sum()
# Out:
#               mpg  cylinders  displacement  \
# model_year
# 70          513.0        196        8161.0
# 71          595.0        156        5873.0
# 72          524.0        163        6114.5
# 73          684.0        255       10275.0
# 74          613.0        142        4637.0
# 75          608.0        168        6166.0
# 76          733.5        192        6725.0
# 77          654.5        153        5359.0
# 78          866.2        193        6401.0
# 79          727.7        169        5994.0
# 80          977.2        120        3359.0
# 81          879.7        134        3924.0
# 82          983.0        130        3995.0
#
#                                                    horsepower  weight  \
# model_year
# 70          1301651501501401982202152251901701601502259595...   97811
# 71          889095?100105100881001651751531501801701751107...   83872
# 72          9580549086165175150153150208155160190971501301...   90656
# ...

# %%
df['model_year'].value_counts()
# Out:
# model_year
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: count, dtype: int64

# %%
#if you did just a group by it is called a lazy op ....

# %%
df.groupby('model_year').sum()
# Out:
#               mpg  cylinders  displacement  \
# model_year
# 70          513.0        196        8161.0
# 71          595.0        156        5873.0
# 72          524.0        163        6114.5
# 73          684.0        255       10275.0
# 74          613.0        142        4637.0
# 75          608.0        168        6166.0
# 76          733.5        192        6725.0
# 77          654.5        153        5359.0
# 78          866.2        193        6401.0
# 79          727.7        169        5994.0
# 80          977.2        120        3359.0
# 81          879.7        134        3924.0
# 82          983.0        130        3995.0
#
#                                                    horsepower  weight  \
# model_year
# 70          1301651501501401982202152251901701601502259595...   97811
# 71          889095?100105100881001651751531501801701751107...   83872
# 72          9580549086165175150153150208155160190971501301...   90656
# ...

# %%
#as you if we did the sum of names if look bad so: agg func are applied for numerical ones

# %%
df.groupby('model_year').sum()['mpg']
# Out:
# model_year
# 70    513.0
# 71    595.0
# 72    524.0
# 73    684.0
# 74    613.0
# 75    608.0
# 76    733.5
# 77    654.5
# 78    866.2
# 79    727.7
# 80    977.2
# 81    879.7
# 82    983.0
# Name: mpg, dtype: float64

# %%
#sometime you need to group by multiple columns :

# %%
df.groupby(['model_year','cylinders']).sum()
# Out:
#                         mpg  displacement  \
# model_year cylinders
# 70         4          177.0         749.0
#            6           82.0         796.0
#            8          254.0        6616.0
# 71         4          357.0        1324.0
#            6          144.0        1947.0
#            8           94.0        2602.0
# 72         3           19.0          70.0
#            4          328.0        1561.5
#            8          177.0        4483.0
# 73         3           18.0          70.0
#            4          250.0        1202.0
#            6          152.0        1698.0
#            8          264.0        7305.0
# 74         4          417.0        1448.0
#            6          125.0        1613.0
#            8           71.0        1576.0
# 75         4          303.0        1378.0
#            6          211.0        2805.0
#            8           94.0        1983.0
# 76         4          401.5        1595.0
#            6          200.0        2214.0
# ...

# %%
df.groupby(['cylinders','model_year']).sum()
# Out:
#                         mpg  displacement  \
# cylinders model_year
# 3         72           19.0          70.0
#           73           18.0          70.0
#           77           21.5          80.0
#           80           23.7          70.0
# 4         70          177.0         749.0
#           71          357.0        1324.0
#           72          328.0        1561.5
#           73          250.0        1202.0
#           74          417.0        1448.0
#           75          303.0        1378.0
#           76          401.5        1595.0
#           77          407.5        1491.0
#           78          502.8        1906.0
#           79          378.3        1363.0
#           80          865.3        2775.0
#           81          689.1        2286.0
#           82          898.0        3320.0
# 5         78           20.3         131.0
#           79           25.4         183.0
#           80           36.4         121.0
# 6         70           82.0         796.0
# ...

# %%
#we can see that the order count :
#so we got a multi_index

# %%
df.groupby(['cylinders','model_year']).sum().index
# Out:
# MultiIndex([(3, 72),
#             (3, 73),
#             (3, 77),
#             (3, 80),
#             (4, 70),
#             (4, 71),
#             (4, 72),
#             (4, 73),
#             (4, 74),
#             (4, 75),
#             (4, 76),
#             (4, 77),
#             (4, 78),
#             (4, 79),
#             (4, 80),
#             (4, 81),
#             (4, 82),
#             (5, 78),
#             (5, 79),
#             (5, 80),
#             (6, 70),
#             (6, 71),
#             (6, 73),
#             (6, 74),
#             (6, 75),
#             (6, 76),
#             (6, 77),
#             (6, 78),
#             (6, 79),
#             (6, 80),
#             (6, 81),
#             (6, 82),
#             (8, 70),
#             (8, 71),
#             (8, 72),
#             (8, 73),
#             (8, 74),
#             (8, 75),
#             (8, 76),
#             (8, 77),
#             (8, 78),
#             (8, 79),
#             (8, 81)],
# ...

# %%
df.groupby(['cylinders','model_year']).sum()['mpg']
# Out:
# cylinders  model_year
# 3          72             19.0
#            73             18.0
#            77             21.5
#            80             23.7
# 4          70            177.0
#            71            357.0
#            72            328.0
#            73            250.0
#            74            417.0
#            75            303.0
#            76            401.5
#            77            407.5
#            78            502.8
#            79            378.3
#            80            865.3
#            81            689.1
#            82            898.0
# 5          78             20.3
#            79             25.4
#            80             36.4
# 6          70             82.0
#            71            144.0
#            73            152.0
#            74            125.0
#            75            211.0
#            76            200.0
#            77             97.5
#            78            228.8
#            79            137.7
# ...

# %%
df.groupby(['cylinders','model_year']).describe()
# Out:
#                        mpg                                                    \
#                      count       mean       std   min     25%    50%     75%
# cylinders model_year
# 3         72           1.0  19.000000       NaN  19.0  19.000  19.00  19.000
#           73           1.0  18.000000       NaN  18.0  18.000  18.00  18.000
#           77           1.0  21.500000       NaN  21.5  21.500  21.50  21.500
#           80           1.0  23.700000       NaN  23.7  23.700  23.70  23.700
# 4         70           7.0  25.285714  1.112697  24.0  24.500  25.00  26.000
#           71          13.0  27.461538  3.502746  22.0  25.000  27.00  30.000
#           72          14.0  23.428571  3.056249  18.0  21.250  23.00  25.750
#           73          11.0  22.727273  3.319365  19.0  20.000  22.00  25.000
#           74          15.0  27.800000  2.932576  24.0  26.000  26.00  31.000
#           75          12.0  25.250000  3.333712  22.0  23.000  24.00  26.000
# ...

# %%
df.groupby(['cylinders','model_year']).describe().transpose()
# Out:
# cylinders                3                                    4               \
# model_year              72      73      77      80           70           71
# mpg          count     1.0     1.0     1.0     1.0     7.000000    13.000000
#              mean     19.0    18.0    21.5    23.7    25.285714    27.461538
#              std       NaN     NaN     NaN     NaN     1.112697     3.502746
#              min      19.0    18.0    21.5    23.7    24.000000    22.000000
#              25%      19.0    18.0    21.5    23.7    24.500000    25.000000
#              50%      19.0    18.0    21.5    23.7    25.000000    27.000000
#              75%      19.0    18.0    21.5    23.7    26.000000    30.000000
#              max      19.0    18.0    21.5    23.7    27.000000    35.000000
# displacement count     1.0     1.0     1.0     1.0     7.000000    13.000000
#              mean     70.0    70.0    80.0    70.0   107.000000   101.846154
# ...

# %%
#usully we use describe with transpose :

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
year_cyl = df.groupby(['cylinders','model_year']).max()

# %%
year_cyl
# Out:
#                        mpg  displacement horsepower  weight  acceleration  \
# cylinders model_year
# 3         72          19.0          70.0         97    2330          13.5
#           73          18.0          70.0         90    2124          13.5
#           77          21.5          80.0        110    2720          13.5
#           80          23.7          70.0        100    2420          12.5
# 4         70          27.0         121.0         95    2672          20.5
#           71          35.0         140.0          ?    2408          20.5
#           72          28.0         140.0         97    2979          23.5
#           73          29.0         140.0         94    2868          21.0
#           74          32.0         140.0         97    2542          21.0
#           75          33.0         140.0         98    2957          18.5
#           76          33.0         140.0         92    3270          22.2
# ...

# %%
year_cyl.index.names
# Out:
# FrozenList(['cylinders', 'model_year'])

# %%
year_cyl.index.levels
# Out:
# FrozenList([[3, 4, 5, 6, 8], [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82]])

# %%
#if we wanna grab data using indexing :

# %%
year_cyl.loc[3] #!!!!! the loc func will work with the most outside level_index
# Out:
#              mpg  displacement horsepower  weight  acceleration  origin  \
# model_year
# 72          19.0          70.0         97    2330          13.5       3
# 73          18.0          70.0         90    2124          13.5       3
# 77          21.5          80.0        110    2720          13.5       3
# 80          23.7          70.0        100    2420          12.5       3
#
#                        name
# model_year
# 72          mazda rx2 coupe
# 73                maxda rx3
# 77               mazda rx-4
# 80            mazda rx-7 gs

# %%
year_cyl.loc[[3,8]]
# Out:
#                        mpg  displacement horsepower  weight  acceleration  \
# cylinders model_year
# 3         72          19.0          70.0         97    2330          13.5
#           73          18.0          70.0         90    2124          13.5
#           77          21.5          80.0        110    2720          13.5
#           80          23.7          70.0        100    2420          12.5
# 8         70          18.0         455.0        225    4732          18.5
#           71          14.0         400.0        180    5140          13.5
#           72          17.0         429.0        208    4633          16.0
#           73          16.0         455.0        230    4997          14.5
#           74          16.0         350.0        150    4699          16.0
#           75          20.0         400.0        170    4668          14.5
#           76          17.5         351.0        180    4380          15.0
# ...

# %%
#if you wanna grap a specific column you can pass a tuple in the parameters  :(we use the mutiIndexing that we talked on the top)

# %%
year_cyl.loc[(8,73)]
# Out:
# mpg                           16.0
# displacement                 455.0
# horsepower                     230
# weight                        4997
# acceleration                  14.5
# origin                           1
# name            pontiac grand prix
# Name: (8, 73), dtype: object

# %%
#THE CROSS SECTION :

# %%
year_cyl
# Out:
#                        mpg  displacement horsepower  weight  acceleration  \
# cylinders model_year
# 3         72          19.0          70.0         97    2330          13.5
#           73          18.0          70.0         90    2124          13.5
#           77          21.5          80.0        110    2720          13.5
#           80          23.7          70.0        100    2420          12.5
# 4         70          27.0         121.0         95    2672          20.5
#           71          35.0         140.0          ?    2408          20.5
#           72          28.0         140.0         97    2979          23.5
#           73          29.0         140.0         94    2868          21.0
#           74          32.0         140.0         97    2542          21.0
#           75          33.0         140.0         98    2957          18.5
#           76          33.0         140.0         92    3270          22.2
# ...

# %%
year_cyl.xs(key = 70 ,level='model_year')
# Out:
#             mpg  displacement horsepower  weight  acceleration  origin  \
# cylinders
# 4          27.0         121.0         95    2672          20.5       3
# 6          22.0         200.0         97    2833          16.0       1
# 8          18.0         455.0        225    4732          18.5       1
#
#                                    name
# cylinders
# 4          volkswagen 1131 deluxe sedan
# 6                       plymouth duster
# 8                      pontiac catalina

# %%
year_cyl.xs(key = 8, level='cylinders')
# Out:
#              mpg  displacement horsepower  weight  acceleration  origin  \
# model_year
# 70          18.0         455.0        225    4732          18.5       1
# 71          14.0         400.0        180    5140          13.5       1
# 72          17.0         429.0        208    4633          16.0       1
# 73          16.0         455.0        230    4997          14.5       1
# 74          16.0         350.0        150    4699          16.0       1
# 75          20.0         400.0        170    4668          14.5       1
# 76          17.5         351.0        180    4380          15.0       1
# 77          17.5         400.0        190    4335          19.0       1
# 78          20.2         318.0        145    4080          15.5       1
# 79          23.9         360.0         90    4360          22.2       1
# 81          26.6         350.0        105    3725          19.0       1
#
#                                          name
# model_year
# ...

# %%
#the XS method acc just one level

# %%
#the purpose of using the XS method is to one commun row existing for each cathegory 
#like the 70th model_year in car with 'x' cylinders

# %%
the_70_year = year_cyl.xs(key = 70, level='model_year')

# %%
the_70_year
# Out:
#             mpg  displacement horsepower  weight  acceleration  origin  \
# cylinders
# 4          27.0         121.0         95    2672          20.5       3
# 6          22.0         200.0         97    2833          16.0       1
# 8          18.0         455.0        225    4732          18.5       1
#
#                                    name
# cylinders
# 4          volkswagen 1131 deluxe sedan
# 6                       plymouth duster
# 8                      pontiac catalina

# %%
#if you need to grop with multiIndex you should do that on the original data frame then apply the group by...

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
filter = df['cylinders'].isin([6,8])
GP = df[filter]

# %%
GP
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 365  20.2          6         200.0         88    3060          17.1
# 366  17.6          6         225.0         85    3465          16.6
# 386  25.0          6         181.0        110    2945          16.4
# 387  38.0          6         262.0         85    3015          17.0
# 389  22.0          6         232.0        112    2835          14.7
#
#      model_year  origin                               name
# 0            70       1          chevrolet chevelle malibu
# ...

# %%
GP
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 365  20.2          6         200.0         88    3060          17.1
# 366  17.6          6         225.0         85    3465          16.6
# 386  25.0          6         181.0        110    2945          16.4
# 387  38.0          6         262.0         85    3015          17.0
# 389  22.0          6         232.0        112    2835          14.7
#
#      model_year  origin                               name
# 0            70       1          chevrolet chevelle malibu
# ...

# %%
GP.groupby(['model_year','cylinders']).max()
# Out:
#                        mpg  displacement horsepower  weight  acceleration  \
# model_year cylinders
# 70         6          22.0         200.0         97    2833          16.0
#            8          18.0         455.0        225    4732          18.5
# 71         6          19.0         258.0         88    3439          15.5
#            8          14.0         400.0        180    5140          13.5
# 72         8          17.0         429.0        208    4633          16.0
# 73         6          23.0         250.0         95    3278          18.0
#            8          16.0         455.0        230    4997          14.5
# 74         6          21.0         258.0          ?    3781          18.0
#            8          16.0         350.0        150    4699          16.0
# 75         6          21.0         258.0         97    3907          21.0
#            8          20.0         400.0        170    4668          14.5
# ...

# %%
year_cyl.sort_index(level = 'model_year',ascending=False)
#as we see is better to sort with the outside level index :
# Out:
#                        mpg  displacement horsepower  weight  acceleration  \
# cylinders model_year
# 6         82          38.0         262.0         85    3015          17.0
# 4         82          44.0         156.0          ?    3035          24.6
# 8         81          26.6         350.0        105    3725          19.0
# 6         81          30.7         231.0         88    3465          19.6
# 4         81          39.1         156.0          ?    3230          20.7
# 6         80          32.7         225.0         90    3381          18.7
# 5         80          36.4         121.0         67    2950          19.9
# 4         80          46.6         156.0          ?    3250          23.7
# 3         80          23.7          70.0        100    2420          12.5
# 8         79          23.9         360.0         90    4360          22.2
# 6         79          28.8         232.0         90    3360          18.2
# ...

# %%
#we gonna see how to specify a particular agg function to a particular agg columns :

# %%
df.agg(['min','max'])['model_year']
# Out:
# min    70
# max    82
# Name: model_year, dtype: int64

# %%
#look for this now :
df.agg({'model_year':['max','sum']})
# Out:
#      model_year
# max          82
# sum       30252
